# %% [markdown]
# **DETECT SELECTION IN SEVERAL POPULATIONS**

# %% [markdown]
# Manhattan plot is a common tool used in genetic association studies to identify genomic regions associated with a particular
# trait or phenotype. In this case, it helps to identify regions of the genome where mutations are under significant selection
# pressure, as indicated by lower log10 p-values. We are focusing on *when_mutation_has_freq2* since when a mutation reaches a
# frequency of 2, it indicates that it has persisted in the population for at least two copies. At this point, it is less likely
# to be a result of random drift (neutral evolution) and more likely to be under the influence of natural selection.

# %%
library("ggplot2")
library("gridExtra")
library("ggpubr")
library(RColorBrewer)

# Retrieve colors in Set2 palette
set2_colors <- brewer.pal(8, "Set2")  # "Set2" palette contains 8 colors

# Print the colors
print(set2_colors)
# Out:
# [1] "#66C2A5" "#FC8D62" "#8DA0CB" "#E78AC3" "#A6D854" "#FFD92F" "#E5C494"
# [8] "#B3B3B3"

# %%
### AFRICAN POPULATIONS ###

# %%
LWK <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/LWK/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(LWK)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781642 .     1               1              1              1
# 2 2781865 .     1               1              1              1
# 3 2781927 .     1               1              1              1
# 4 2782572 .     1               1              1              1
# 5 2783658 .     1               1              1              1
# 6 2784657 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.1184090
# 2 1              1             1             1             ⋯ -0.9298430
# 3 1              1             1             1             ⋯ -1.0582400
# 4 1              1             1             1             ⋯ -0.1860750
# 5 1              1             1             1             ⋯  1.0000000
# 6 1              1             1             1             ⋯ -0.0418245
#   X184.981262 X133.128357 X95.810577 X68.953499 X49.624844  X35.714287
# 1 -0.1638780  -0.2162100  -0.2904730 -0.370193  -0.00001189 -1.87199e-05
# 2 -0.4803940  -0.4096790  -0.3640980 -0.099042  -0.07355400 -1.47872e-06
# 3 -1.0142300  -0.2935240  -0.4092850 -0.843033  -0.54066200 -3.48473e-01
# 4 -0.1998930  -0.2187410  -0.2039450 -0.211564  -0.17623900 -9.76327e-02
# 5  1.0000000   1.0000000   1.0000000  1.000000   1.00000000 -6.76691e-01
# 6 -0.0645762  -0.0939864  -0.0762433 -0.168586  -0.36986300 -9.02710e-01
#   X0.000000 when_DAF_is_half when_mutation_has_freq2
# 1 0         -0.521446        -0.0826921
# 2 0         -0.502876        -0.4894340
# 3 0         -1.117520        -1.0831700
# 4 0         -0.167312        -0.1453570
# 5 0         -1.584070        -0.6106680
# 6 0         -0.171228        -0.6694810

# %%
LWK_columns <- LWK[, c(1, ncol(LWK))]
write.csv(LWK_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/africans_data/LWK_pos_pvalue.csv", row.names = FALSE)

# %%
LWK_plot <- plot(LWK$pos, -(LWK$when_mutation_has_freq2), pch = 19, col = "#8DA0CB", xlab = "Genomic Position", ylab = "log10(p-value)", main = "LWK",cex = 1.5, yaxp = c(0, 10, 5),cex.lab = 1.2)
# Out:
# Plot with title “LWK”

# %%
ESN <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/ESN/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(ESN)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781514 .     1               1              1              1
# 2 2781584 .     1               1              1              1
# 3 2781635 .     1               1              1              1
# 4 2781642 .     1               1              1              1
# 5 2781865 .     1               1              1              1
# 6 2781927 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.166468
# 2 1              1             1             1             ⋯ -0.195486
# 3 1              1             1             1             ⋯ -0.833012
# 4 1              1             1             1             ⋯ -0.121280
# 5 1              1             1             1             ⋯ -0.266384
# 6 1              1             1             1             ⋯ -0.170070
#   X184.981262 X133.128357 X95.810577 X68.953499 X49.624844 X35.714287 X0.000000
# 1 -0.1633020  -0.0304907  -0.0783616 -0.187772  -0.2355050 -0.180105  0
# 2 -0.0470885  -0.1543830  -0.0941514 -0.121442  -0.1441770 -0.170387  0
# 3 -0.4837690  -0.9173760  -0.9359220 -0.195784  -0.1095390 -0.139305  0
# 4 -0.1852730  -0.2536610  -0.3541900 -0.162419  -0.0553357 -0.108377  0
# 5 -0.3640380  -0.2497360  -0.2750760 -0.265679  -0.8029150 -0.539360  0
# 6 -0.2247610  -0.2836910  -0.2261890 -0.336020  -0.4659700 -0.645897  0
#   when_DAF_is_half when_mutation_has_freq2
# 1 -0.1074540       -0.4711580
# 2 -0.0951265       -0.3480300
# 3 -0.7860770       -1.0504800
# 4 -0.4089780       -0.0232036
# 5 -0.3350830       -0.9164550
# 6 -0.3241110       -1.3473000

# %%
ESN_columns <- ESN[, c(1, ncol(ESN))]
write.csv(ESN_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks//africans_data/ESN_pos_pvalue.csv", row.names = FALSE)

# %%
ESN_plot <- plot(ESN$pos, -(ESN$when_mutation_has_freq2), pch=19, col = "#66C2A5", xlab="Genomic Position", ylab="log10(p-value)", main ="ESN", cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “ESN”

# %%
GWD <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/GWD/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(GWD)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781514 .     1               1              1              1
# 2 2781584 .     1               1              1              1
# 3 2781635 .     1               1              1              1
# 4 2781642 .     1               1              1              1
# 5 2781865 .     1               1              1              1
# 6 2782386 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.339229
# 2 1              1             1             1             ⋯ -2.115460
# 3 1              1             1             1             ⋯ -0.708444
# 4 1              1             1             1             ⋯ -0.293793
# 5 1              1             1             1             ⋯  1.000000
# 6 1              1             1             1             ⋯  1.000000
#   X184.981262 X133.128357 X95.810577 X68.953499 X49.624844 X35.714287 X0.000000
# 1 -0.193052   -0.144900   -0.282910  -0.411491  -0.244936  -0.2916490 0
# 2 -2.298450   -2.052000   -2.466710  -2.018510  -1.317800  -1.5680100 0
# 3 -0.767915   -0.536291   -0.316172  -0.187841  -0.152155  -0.1646880 0
# 4 -0.387192   -0.178903   -0.259375  -0.117266  -0.180686  -0.0666416 0
# 5 -3.298390   -3.140550   -3.193370  -2.681820  -1.800210  -1.7143900 0
# 6  1.000000   -0.530063   -0.657031  -0.888510  -1.053060  -0.6741820 0
#   when_DAF_is_half when_mutation_has_freq2
# 1 -0.450937        -0.775258
# 2 -1.857430        -0.467748
# 3 -0.327542        -2.461210
# 4 -0.368471        -0.174437
# 5 -1.695450        -3.034880
# 6 -1.132350        -0.426668

# %%
GWD_columns <- GWD[, c(1, ncol(GWD))]
write.csv(GWD_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks//africans_data/GWD_pos_pvalue.csv", row.names = FALSE)

# %%
GWD_plot <- plot(GWD$pos, -(GWD$when_mutation_has_freq2), pch = 19, col = "#FC8D62", xlab = "Genomic Position", ylab = "log10(p-value)", main = "GWD", cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “GWD”

# %%
MSL <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/MSL/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(MSL)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781514 .     1               1              1              1
# 2 2781584 .     1               1              1              1
# 3 2781635 .     1               1              1              1
# 4 2781865 .     1               1              1              1
# 5 2781927 .     1               1              1              1
# 6 2783658 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.0136754
# 2 1              1             1             1             ⋯ -1.1648600
# 3 1              1             1             1             ⋯ -1.9573600
# 4 1              1             1             1             ⋯ -0.1382090
# 5 1              1             1             1             ⋯ -0.4013970
# 6 1              1             1             1             ⋯ -0.0589885
#   X184.981262 X133.128357 X95.810577 X68.953499  X49.624844  X35.714287
# 1 -0.00752785 -0.03071400 -0.0790543 -0.00954398 -0.00392873 -0.0111185
# 2 -2.07488000 -1.38451000 -1.0171100 -1.10349000 -0.72307600 -0.6813460
# 3 -1.74453000 -1.96630000 -1.3042400 -1.63909000 -2.37917000 -2.1754900
# 4 -0.02209630 -0.00423044 -0.0135946 -0.00104831  0.00000000  0.0000000
# 5 -0.18003500 -0.21586300 -0.2130100 -0.23700900 -0.13138700 -0.0214001
# 6 -0.11448300 -0.24187300 -0.1492140 -0.08367280 -0.04696250  0.0000000
#   X0.000000 when_DAF_is_half when_mutation_has_freq2
# 1 0         -0.010442        -0.1174050
# 2 0         -1.456260        -0.3105280
# 3 0         -2.033520        -0.6728530
# 4 0         -0.185114        -0.4561510
# 5 0         -0.611305        -0.6766260
# 6 0         -0.134864        -0.0653668

# %%
MSL_columns <- MSL[, c(1, ncol(MSL))]
write.csv(MSL_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks//africans_data/MSL_pos_pvalue.csv", row.names = FALSE)

# %%
MSL_plot <- plot(MSL$pos, -(MSL$when_mutation_has_freq2), pch = 19, col = "#E78AC3", xlab = "Genomic Position", ylab = "log10(p-value)", main = "MSL", cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “MSL”

# %%
YRI <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/YRI/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(YRI)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781584 .     1               1              1              1
# 2 2781635 .     1               1              1              1
# 3 2781642 .     1               1              1              1
# 4 2781927 .     1               1              1              1
# 5 2782597 .     1               1              1              1
# 6 2783658 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.234540
# 2 1              1             1             1             ⋯ -0.133075
# 3 1              1             1             1             ⋯ -0.237539
# 4 1              1             1             1             ⋯ -0.837992
# 5 1              1             1             1             ⋯ -0.337618
# 6 1              1             1             1             ⋯ -0.119464
#   X184.981262 X133.128357 X95.810577 X68.953499 X49.624844 X35.714287 X0.000000
# 1 -0.2501550  -0.227736   -0.2127810 -0.5659020 -0.4135570 -0.6552640 0
# 2 -0.3189780  -0.264945   -0.0875422 -0.2345220 -0.0871074 -0.1109900 0
# 3 -0.2984380  -0.367273   -0.4598840 -0.2105470 -0.3219440 -0.5167580 0
# 4 -0.8435180  -0.778487   -0.8953910 -1.2249300 -0.7058940 -0.3632000 0
# 5 -0.4064530  -0.565045   -0.0864026 -0.1380790 -0.2111780 -0.3139470 0
# 6 -0.0927931  -0.126422   -0.1077460 -0.0466026 -0.0494790 -0.0339792 0
#   when_DAF_is_half when_mutation_has_freq2
# 1 -0.241883        -0.250652
# 2 -0.116743        -0.515658
# 3 -1.117290        -0.133245
# 4 -1.324310        -0.316513
# 5 -0.270393        -0.168732
# 6 -0.190820        -0.125588

# %%
YRI_columns <- YRI[, c(1, ncol(YRI))]
write.csv(YRI_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks//africans_data/YRI_pos_pvalue.csv", row.names = FALSE)

# %%
YRI_plot <- plot(YRI$pos, -(YRI$when_mutation_has_freq2), pch = 19, col = "#A6D854", xlab = "Genomic Position", ylab = "log10(p-value)", main = "YRI" , cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “YRI”

# %%
# Combine data frames
LWK$Population <- "LWK"
ESN$Population <- "ESN"
GWD$Population <- "GWD"
MSL$Population <- "MSL"
YRI$Population <- "YRI"

combined_data <- rbind(LWK, ESN, GWD, MSL, YRI)

plot_combined <- ggplot(data = combined_data, aes(x = pos, y = -(when_mutation_has_freq2), color = Population)) +
  geom_point(pch = 19, size = 4) +
  labs(x = "Genomic Position", y = "log10(p-value)") +
  theme_light() +
  geom_hline(yintercept = 6, color = "red") +
  scale_color_brewer(palette = "Set2") + theme(text = element_text(size = 15)) 

print(plot_combined)

ggsave("africans_threshold.png", plot_combined, width = 18, height = 6)
# Out:
# plot without title

# %%
## SELECT JUST POSITION LOWER THAN THRESHOLD (log10 p-value < -6)

# Define file paths for the five .sele files
file_paths <- c(
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/LWK/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/ESN/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/GWD/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/MSL/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/YRI/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele"
)

# Read the files
LWK <- read.table(file_paths[1], header = TRUE)
ESN <- read.table(file_paths[2], header = TRUE)
GWD <- read.table(file_paths[3], header = TRUE)
MSL <- read.table(file_paths[4], header = TRUE)
YRI <- read.table(file_paths[5], header = TRUE)

# Function to subset data based on log10 p-value
subset_data <- function(data, population) {
  subset(data, when_mutation_has_freq2 < -6) %>%
    mutate(population = population)
}

# Define data frames and corresponding population names
file_pop <- list(
  list(data = LWK, population = "LWK"),
  list(data = ESN, population = "ESN"),
  list(data = GWD, population = "GWD"),
  list(data = MSL, population = "MSL"),
  list(data = YRI, population = "YRI")
)

# Subset and bind data from all files
africans_low_pvalue <- do.call(rbind, lapply(file_pop, function(fp) {
  subset_data(fp$data, fp$population)
}))

# Save the combined data to a single file
write.csv(africans_low_pvalue, "africans_low_pvalue.csv", row.names = FALSE)

filtered <- read.csv("/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/africans_low_pvalue.csv")
head(filtered)
cat("Number of rows and columns:", paste(dim(filtered), collapse = "x"))
# Out:
#   pos      rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 17951099 .     1               1              1              1
# 2 20315815 .     1               1              1              1
# 3 20317564 .     1               1              1              1
# 4 23370843 .     1               1              1              1
# 5 10433671 .     1               1              1              1
# 6 18440969 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X184.981262
# 1 1              1             1             1             ⋯ -0.906531
# 2 1              1             1             1             ⋯ -1.597710
# 3 1              1             1             1             ⋯ -0.720711
# 4 1              1             1             1             ⋯ -2.502140
# 5 1              1             1             1             ⋯ -1.230430
# 6 1              1             1             1             ⋯ -1.011410
#   X133.128357 X95.810577 X68.953499 X49.624844 X35.714287 X0.000000
# 1 -1.217870   -1.148250  -1.414110  -0.842883  -0.371460  0
# 2 -1.784550   -2.075210  -1.568870  -1.530930  -0.813921  0
# 3 -0.567685   -0.650674  -0.786545  -0.689192  -0.303330  0
# 4 -2.010350   -1.696540  -1.284260  -0.871876  -0.662442  0
# 5 -0.813726   -0.493243  -0.237581  -0.202660  -0.302776  0
# 6 -0.750136   -0.915622  -0.691098  -0.532403  -0.327363  0
#   when_DAF_is_half when_mutation_has_freq2 population
# 1 -1.572070        -6.61750                LWK
# 2 -2.395940        -9.37493                LWK
# 3 -1.141920        -7.23160                LWK
# 4 -3.826400        -7.05065                LWK
# 5 -0.521846        -6.72735                ESN
# 6 -1.229320        -6.37140                ESN
# Number of rows and columns: 24x36

# %%
plot_threshold <- ggplot(filtered, aes(x = pos, y = -(when_mutation_has_freq2), color = population)) +
  geom_point(size = 4) +
  labs(x = "Genomic position", y = "log10 p-value", title = "African Populations") + 
  theme_minimal() + 
scale_color_brewer(palette = "Set2") + theme(text = element_text(size = 15),
        plot.title = element_text(hjust = 0.5))


print(plot_threshold)
#ggsave("africans_low_pvalue_r.png", plot_threshold, width = 20, height = 6)
# Out:
# plot without title

# %%
### EUROPEAN POPULATIONS ###

# %%
GBR <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/GBR/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(GBR)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781604 .     1               1              1              1
# 2 2781635 .     1               1              1              1
# 3 2781927 .     1               1              1              1
# 4 2781986 .     1               1              1              1
# 5 2782116 .     1               1              1              1
# 6 2782161 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.249885
# 2 1              1             1             1             ⋯ -0.477853
# 3 1              1             1             1             ⋯ -0.180894
# 4 1              1             1             1             ⋯ -0.180894
# 5 1              1             1             1             ⋯ -0.339636
# 6 1              1             1             1             ⋯ -0.311304
#   X184.981262 X133.128357 X95.810577 X68.953499 X49.624844 X35.714287 X0.000000
# 1 -0.369358   -0.0888971  -0.2458440  0.000000   0.000000   0.000000  0
# 2 -0.209007   -0.4451880  -0.0413312 -0.158950   0.000000   0.000000  0
# 3 -0.256423   -0.1875170  -0.2706230 -0.231661  -0.130391  -0.130391  0
# 4 -0.256423   -0.1875170  -0.2706230 -0.231661  -0.130391  -0.130391  0
# 5 -0.458530   -0.1129770  -0.2835200  0.000000   0.000000   0.000000  0
# 6 -0.227053   -0.1759160  -0.0554204 -0.016316   0.000000   0.000000  0
#   when_DAF_is_half when_mutation_has_freq2
# 1 -0.522252        -0.456328
# 2 -0.488710        -0.209925
# 3 -0.221039        -0.485906
# 4 -0.221039        -0.485906
# 5 -0.640993        -0.976645
# 6 -0.371537        -0.141249

# %%
GBR_plot <- plot(GBR$pos, -(GBR$when_mutation_has_freq2), pch = 19, col = "lightblue", xlab = "Genomic Position", ylab = "log10(p-value)", main = "GBR" , cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “GBR”

# %%
FIN <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/FIN/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(FIN)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781604 .     1               1              1              1
# 2 2781635 .     1               1              1              1
# 3 2781927 .     1               1              1              1
# 4 2781986 .     1               1              1              1
# 5 2782116 .     1               1              1              1
# 6 2782161 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.401235
# 2 1              1             1             1             ⋯ -0.174842
# 3 1              1             1             1             ⋯ -0.407761
# 4 1              1             1             1             ⋯ -0.407761
# 5 1              1             1             1             ⋯ -0.401235
# 6 1              1             1             1             ⋯ -0.233220
#   X184.981262 X133.128357 X95.810577 X68.953499 X49.624844 X35.714287 X0.000000
# 1 -0.473964   -0.236110   -0.3238680 -0.1267090 -0.0952350 -0.0608378 0
# 2 -0.159220   -0.214557   -0.0696269 -0.0860288 -0.0940255 -0.1088940 0
# 3 -0.370574   -0.268280   -0.3814070 -0.4634590 -0.2961320 -0.5959180 0
# 4 -0.370574   -0.268280   -0.3814070 -0.4634590 -0.2961320 -0.5959180 0
# 5 -0.473964   -0.236110   -0.3238680 -0.1267090 -0.0952350 -0.0608378 0
# 6 -0.259991   -0.198133   -0.1120840 -0.0619963 -0.0572686 -0.0538726 0
#   when_DAF_is_half when_mutation_has_freq2
# 1 -0.308731        -0.1094940
# 2 -0.242437        -0.2394300
# 3 -0.683126        -0.9218420
# 4 -0.683126        -0.9218420
# 5 -0.308731        -0.1094940
# 6 -0.245689        -0.0363945

# %%
FIN_plot <- plot(FIN$pos, -(FIN$when_mutation_has_freq2), pch = 19, col = "lightpink", xlab = "Genomic Position", ylab = "log10(p-value)", main = "FIN" , cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “FIN”

# %%
IBS <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/IBS/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(IBS)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781514 .     1               1              1              1
# 2 2781604 .     1               1              1              1
# 3 2781635 .     1               1              1              1
# 4 2781927 .     1               1              1              1
# 5 2781986 .     1               1              1              1
# 6 2782048 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.0771751
# 2 1              1             1             1             ⋯ -0.5492980
# 3 1              1             1             1             ⋯ -0.6907230
# 4 1              1             1             1             ⋯ -0.2931550
# 5 1              1             1             1             ⋯ -0.2931550
# 6 1              1             1             1             ⋯  1.0000000
#   X184.981262 X133.128357 X95.810577 X68.953499 X49.624844 X35.714287 X0.000000
# 1 -0.0991587  -0.0894372  -0.0701501 -0.0707925 -0.0926875 -0.0952254 0
# 2 -0.6430870  -0.4288300  -0.5171080 -0.5205040 -0.2961570 -0.1186770 0
# 3 -0.7798550  -0.5131050  -0.8114680 -0.5971070 -0.6923870 -0.7812050 0
# 4 -0.2715830  -0.0701448  -0.1012040 -0.1041790 -0.0953636 -0.0656362 0
# 5 -0.2715830  -0.0701448  -0.1012040 -0.1041790 -0.0953636 -0.0656362 0
# 6 -0.2918080  -0.4300500  -0.2016640 -0.2720060 -0.3172290 -0.1231870 0
#   when_DAF_is_half when_mutation_has_freq2
# 1 -0.114935        -0.430028
# 2 -0.616622        -0.487534
# 3 -0.963285        -0.350884
# 4 -0.116232        -2.076860
# 5 -0.116232        -2.076860
# 6 -0.401077        -0.279030

# %%
IBS_plot <- plot(IBS$pos, -(IBS$when_mutation_has_freq2), pch = 19, col = "gold", xlab = "Genomic Position", ylab = "log10(p-value)", main = "IBS" , cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “IBS”

# %%
TSI <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/TSI/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(TSI)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781604 .     1               1              1              1
# 2 2781635 .     1               1              1              1
# 3 2781927 .     1               1              1              1
# 4 2781986 .     1               1              1              1
# 5 2782116 .     1               1              1              1
# 6 2782161 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.1000070
# 2 1              1             1             1             ⋯ -0.5938060
# 3 1              1             1             1             ⋯ -0.4806680
# 4 1              1             1             1             ⋯ -0.4806680
# 5 1              1             1             1             ⋯ -0.0658398
# 6 1              1             1             1             ⋯ -1.1587600
#   X184.981262 X133.128357 X95.810577  X68.953499 X49.624844   X35.714287
# 1 -0.0708474  -0.0941116  -0.00819142 -0.0624160 -4.17326e-01 -2.05973e-05
# 2 -0.6723940  -0.1824460  -0.14755800 -0.2140360 -5.22586e-05 -2.00428e-05
# 3 -0.4499270  -0.5129960  -1.33184000 -0.3583910 -1.49705e-01 -5.83239e-01
# 4 -0.4499270  -0.5129960  -1.33184000 -0.3583910 -1.49705e-01 -5.83239e-01
# 5 -0.0508219  -0.0746811  -0.00642735 -0.0549163 -3.98010e-01 -1.89802e-05
# 6 -0.6086410  -0.4775580  -0.32658300 -0.2597190 -2.14569e-01 -1.04867e-05
#   X0.000000 when_DAF_is_half when_mutation_has_freq2
# 1 0         -0.3134250       -0.2886860
# 2 0         -0.8762560       -0.9657470
# 3 0         -0.3023520       -0.5354200
# 4 0         -0.3023520       -0.5354200
# 5 0         -0.0989439       -0.0495225
# 6 0         -0.6706350       -0.5259030

# %%
TSI_plot <- plot(TSI$pos, -(TSI$when_mutation_has_freq2), pch = 19, col = "lightgreen", xlab = "Genomic Position", ylab = "log10(p-value)", main = "TSI" , cex = 1.5, ylim = c(0, 10), cex.lab = 1.2)
# Out:
# Plot with title “TSI”

# %%
# Combine data frames
GBR$Population <- "GBR"
FIN$Population <- "FIN"
IBS$Population <- "IBS"
TSI$Population <- "TSI"

combined_data <- rbind(GBR, FIN, IBS, TSI)

plot_combined <- ggplot(data = combined_data, aes(x = pos, y = -(when_mutation_has_freq2), color = Population)) +
  geom_point(pch = 19, size = 4) +
  labs(x = "Genomic Position", y = "log10(p-value)") +
  theme_light() +
  geom_hline(yintercept = 6, color = "red") +
  scale_color_manual(values = c("GBR" = "lightblue", "FIN" = "lightpink", "IBS" = "gold", "TSI" = "lightgreen")) + theme(text = element_text(size = 15)) 

print(plot_combined)

ggsave("europeans_threshold.png", plot_combined, width = 18, height = 6)
# Out:
# plot without title

# %%
1000g_ppl_phased_haplotypes_selection.sele

# %%
## SELECT JUST POSITION LOWER THAN THRESHOLD (log10 p-value < -6)

# Define file paths for the five .sele files
file_paths <- c(
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/GBR/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/FIN/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/IBS/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/TSI/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
)

# Read the files
GBR <- read.table(file_paths[1], header = TRUE)
FIN <- read.table(file_paths[2], header = TRUE)
IBS <- read.table(file_paths[3], header = TRUE)
TSI <- read.table(file_paths[4], header = TRUE)

# Function to subset data based on log10 p-value
subset_data <- function(data, population) {
  subset(data, when_mutation_has_freq2 < -6) %>%
    mutate(population = population)
}

# Define data frames and corresponding population names
file_pop <- list(
  list(data = GBR, population = "GBR"),
  list(data = FIN, population = "FIN"),
  list(data = IBS, population = "IBS"),
  list(data = TSI, population = "TSI"),
)

# Subset and bind data from all files
europeans_low_pvalue <- do.call(rbind, lapply(file_pop, function(fp) {
  subset_data(fp$data, fp$population)
}))

# Save the combined data to a single file
write.csv(europeans_low_pvalue, "europeans_low_pvalue.csv", row.names = FALSE)

filtered <- read.csv("/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/europeans_data/europeans_low_pvalue.csv")
head(filtered)
cat("Number of rows and columns:", paste(dim(filtered), collapse = "x"))
# Out:
# Error in c("/home/ari/ari-intern/people/ari/ariadna-intern/steps/GBR/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", : argument 5 is empty
# Traceback:
