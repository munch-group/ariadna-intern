# %% [markdown]
# **MANHATTAN PLOTS TO DETECT SELECTION IN AFRICAN POPULATIONS**

# %% [markdown]
# Manhattan plot is a common tool used in genetic association studies to identify genomic regions associated with a particular
# trait or phenotype. In this case, it helps to identify regions of the genome where mutations are under significant selection
# pressure, as indicated by lower log10 p-values. We are focusing on *when_mutation_has_freq2* since when a mutation reaches a
# frequency of 2, it indicates that it has persisted in the population for at least two copies. At this point, it is less likely
# to be a result of random drift (neutral evolution) and more likely to be under the influence of natural selection.

# %%
library("gridExtra")
library("ggpubr")
library("ggplot2")
# Out:
# Loading required package: ggplot2

# %%
LWK <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/LWK/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(LWK)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781642 .     1               1              1              1
# 2 2781865 .     1               1              1              1
# 3 2781927 .     1               1              1              1
# 4 2782572 .     1               1              1              1
# 5 2783658 .     1               1              1              1
# 6 2784657 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.1184090
# 2 1              1             1             1             ⋯ -0.9298430
# 3 1              1             1             1             ⋯ -1.0582400
# 4 1              1             1             1             ⋯ -0.1860750
# 5 1              1             1             1             ⋯  1.0000000
# 6 1              1             1             1             ⋯ -0.0418245
# ...

# %%
LWK_columns <- LWK[, c(1, ncol(LWK))]
write.csv(LWK_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/LWK_pos_pvalue.csv", row.names = FALSE)

# %%
LWK_plot <- plot(LWK$pos, -(LWK$when_mutation_has_freq2), pch = 19, col = "lightblue", xlab = "Genomic Position", ylab = "log10(p-value)", main = "Evidence for selection in LWK",cex = 1.5, yaxp = c(0, 10, 5))
ggsave("LWK_r.png", plot_combined, width = 8, height = 8)
# Out:
# Error in ggsave("LWK_r.png", plot_combined, width = 8, height = 8): could not find function "ggsave"
# Traceback:
# Plot with title “Evidence for selection in LWK”

# %%
ESN <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/ESN/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(ESN)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781514 .     1               1              1              1
# 2 2781584 .     1               1              1              1
# 3 2781635 .     1               1              1              1
# 4 2781642 .     1               1              1              1
# 5 2781865 .     1               1              1              1
# 6 2781927 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.166468
# 2 1              1             1             1             ⋯ -0.195486
# 3 1              1             1             1             ⋯ -0.833012
# 4 1              1             1             1             ⋯ -0.121280
# 5 1              1             1             1             ⋯ -0.266384
# 6 1              1             1             1             ⋯ -0.170070
# ...

# %%
ESN_columns <- ESN[, c(1, ncol(ESN))]
write.csv(ESN_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/ESN_pos_pvalue.csv", row.names = FALSE)

# %%
ESN_plot <- plot(ESN$pos, -(ESN$when_mutation_has_freq2), pch=19, col = "lightpink", xlab="Genomic Position", ylab="log10(p-value)", main ="Evidence for selection in ESN", cex = 1.5, ylim = c(0, 10))
ggsave("ESN_r.png", plot_combined, width = 8, height = 8)
# Out:
# Plot with title “Evidence for selection in ESN”

# %%
GWD <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/GWD/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(GWD)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781514 .     1               1              1              1
# 2 2781584 .     1               1              1              1
# 3 2781635 .     1               1              1              1
# 4 2781642 .     1               1              1              1
# 5 2781865 .     1               1              1              1
# 6 2782386 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.339229
# 2 1              1             1             1             ⋯ -2.115460
# 3 1              1             1             1             ⋯ -0.708444
# 4 1              1             1             1             ⋯ -0.293793
# 5 1              1             1             1             ⋯  1.000000
# 6 1              1             1             1             ⋯  1.000000
# ...

# %%
GWD_columns <- GWD[, c(1, ncol(GWD))]
write.csv(GWD_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/GWD_pos_pvalue.csv", row.names = FALSE)

# %%
GWD_plot <- plot(GWD$pos, -(GWD$when_mutation_has_freq2), pch = 19, col = "gold", xlab = "Genomic Position", ylab = "log10(p-value)", main = "Evidence for selection in GWD", cex = 1.5, ylim = c(0, 10))
ggsave("GWD_r.png", plot_combined, width = 8, height = 8)
# Out:
# Plot with title “Evidence for selection in GWD”

# %%
MSL <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/MSL/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(MSL)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781514 .     1               1              1              1
# 2 2781584 .     1               1              1              1
# 3 2781635 .     1               1              1              1
# 4 2781865 .     1               1              1              1
# 5 2781927 .     1               1              1              1
# 6 2783658 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.0136754
# 2 1              1             1             1             ⋯ -1.1648600
# 3 1              1             1             1             ⋯ -1.9573600
# 4 1              1             1             1             ⋯ -0.1382090
# 5 1              1             1             1             ⋯ -0.4013970
# 6 1              1             1             1             ⋯ -0.0589885
# ...

# %%
MSL_columns <- MSL[, c(1, ncol(MSL))]
write.csv(MSL_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/MSL_pos_pvalue.csv", row.names = FALSE)

# %%
MSL_plot <- plot(MSL$pos, -(MSL$when_mutation_has_freq2), pch = 19, col = "orange2", xlab = "Genomic Position", ylab = "log10(p-value)", main = "Evidence for selection in MSL", cex = 1.5, ylim = c(0, 10))
ggsave("MSL_r.png", plot_combined, width = 8, height = 8)
# Out:
# Plot with title “Evidence for selection in MSL”

# %%
YRI <- read.table("/home/ari/ari-intern/people/ari/ariadna-intern/steps/YRI/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele", header = TRUE)
head(YRI)
# Out:
#   pos     rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 2781584 .     1               1              1              1
# 2 2781635 .     1               1              1              1
# 3 2781642 .     1               1              1              1
# 4 2781927 .     1               1              1              1
# 5 2782597 .     1               1              1              1
# 6 2783658 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X257.030640
# 1 1              1             1             1             ⋯ -0.234540
# 2 1              1             1             1             ⋯ -0.133075
# 3 1              1             1             1             ⋯ -0.237539
# 4 1              1             1             1             ⋯ -0.837992
# 5 1              1             1             1             ⋯ -0.337618
# 6 1              1             1             1             ⋯ -0.119464
# ...

# %%
YRI_columns <- YRI[, c(1, ncol(YRI))]
write.csv(YRI_columns, file = "/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/YRI_pos_pvalue.csv", row.names = FALSE)

# %%
YRI_plot <- plot(YRI$pos, -(YRI$when_mutation_has_freq2), pch = 19, col = "lightgreen", xlab = "Genomic Position", ylab = "log10(p-value)", main = "Evidence for selection in YRI" , cex = 1.5, ylim = c(0, 10))
ggsave("YRI_r.png", plot_combined, width = 8, height = 8)
# Out:
# Plot with title “Evidence for selection in YRI”

# %%
# Combine data frames
LWK$Population <- "LWK"
ESN$Population <- "ESN"
GWD$Population <- "GWD"
MSL$Population <- "MSL"
YRI$Population <- "YRI"

combined_data <- rbind(LWK, ESN, GWD, MSL, YRI)

plot_combined <- ggplot(data = combined_data, aes(x = pos, y = -(when_mutation_has_freq2), color = Population)) +
  geom_point(pch = 19, size = 3) +
  labs(x = "Genomic Position", y = "log10(p-value)", title = "Evidence for selection in African Populations") +
  theme_light() +
  geom_hline(yintercept = 6, color = "red") +
  scale_color_manual(values = c("LWK" = "lightblue", "ESN" = "lightpink", "GWD" = "gold", "MSL" = "orange2", "YRI" = "lightgreen")) +
  theme(
    axis.title = element_text(size = 14),  
    axis.text = element_text(size = 12),  
    plot.title = element_text(size = 16, hjust = 0.5)  
  )

print(plot_combined)

ggsave("africans_plot_threshold_r.png", plot_combined, width = 20, height = 8)
# Out:
# plot without title

# %%
## SELECT JUST POSITION LOWER THAN THRESHOLD (log10 p-value < -6)

# Define file paths for the five .sele files
file_paths <- c(
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/LWK/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/ESN/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/GWD/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/MSL/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele",
  "/home/ari/ari-intern/people/ari/ariadna-intern/steps/YRI/relate/run_relate/1000g_ppl_phased_haplotypes_selection.sele"
)

# Read the files
LWK <- read.table(file_paths[1], header = TRUE)
ESN <- read.table(file_paths[2], header = TRUE)
GWD <- read.table(file_paths[3], header = TRUE)
MSL <- read.table(file_paths[4], header = TRUE)
YRI <- read.table(file_paths[5], header = TRUE)

# Function to subset data based on log10 p-value
subset_data <- function(data, population) {
  subset(data, when_mutation_has_freq2 < -6) %>%
    mutate(population = population)
}

# Define data frames and corresponding population names
file_pop <- list(
  list(data = LWK, population = "LWK"),
  list(data = ESN, population = "ESN"),
  list(data = GWD, population = "GWD"),
  list(data = MSL, population = "MSL"),
  list(data = YRI, population = "YRI")
)

# Subset and bind data from all files
africans_low_pvalue <- do.call(rbind, lapply(file_pop, function(fp) {
  subset_data(fp$data, fp$population)
}))

# Save the combined data to a single file
write.csv(africans_low_pvalue, "africans_low_pvalue.csv", row.names = FALSE)

filtered <- read.csv("/home/ari/ari-intern/people/ari/ariadna-intern/notebooks/africans_low_pvalue.csv")
head(filtered)
cat("Number of rows and columns:", paste(dim(filtered), collapse = "x"))
# Out:
#   pos      rs_id X3571428.500000 X357142.937500 X257030.656250 X184981.281250
# 1 17951099 .     1               1              1              1
# 2 20315815 .     1               1              1              1
# 3 20317564 .     1               1              1              1
# 4 23370843 .     1               1              1              1
# 5 10433671 .     1               1              1              1
# 6 18440969 .     1               1              1              1
#   X133128.375000 X95810.585938 X68953.507812 X49624.847656 ⋯ X184.981262
# 1 1              1             1             1             ⋯ -0.906531
# 2 1              1             1             1             ⋯ -1.597710
# 3 1              1             1             1             ⋯ -0.720711
# 4 1              1             1             1             ⋯ -2.502140
# 5 1              1             1             1             ⋯ -1.230430
# 6 1              1             1             1             ⋯ -1.011410
# ...

# %%
plot_threshold <- ggplot(filtered, aes(x = pos, y = -(when_mutation_has_freq2), color = population)) +
  geom_point(size = 4) +
  labs(x = "Genomic position", y = "log10 p-value", title = "Log10 p-value vs. Position for African Populations") + 
  theme_minimal() +
scale_color_manual(values = c("LWK" = "lightblue", "ESN" = "lightpink", "GWD" = "gold", "MSL" = "orange2", "YRI" = "lightgreen"))

print(plot_threshold)
ggsave("africans_low_pvalue_r.png", plot_threshold, width = 20, height = 6)
# Out:
# plot without title

# %%
# focus on region having overlapping genes(1.5e+07 to 2.5e+07)
filtered_pos <- filtered[filtered$pos >= 1.5e+07 & filtered$pos <= 2.5e+07, ]
cat("Number of rows and columns:", paste(dim(filtered_pos), collapse = "x"))

ggplot(filtered_pos, aes(x = pos, y = -(when_mutation_has_freq2), color = population)) +
  geom_point(size = 4) +
  labs(x = "Position", y = "log10 p-value", title = "Log10 p-value vs. Position for African Populations (1.5e+07 to 2.5e+07)") +
  theme_minimal() +
scale_color_manual(values = c("LWK" = "lightblue", "ESN" = "lightpink", "GWD" = "gold", "MSL" = "orange2", "YRI" = "lightgreen"))
# Out:
# Number of rows and columns: 15x36
# plot without title

# %%
# focus on region having overlapping genes(1.8e+07 to 1.9e+07)
filtered_pos_2 <- filtered[filtered$pos >= 1.8e+07 & filtered$pos <= 1.9e+07, ]
cat("Number of rows and columns:", paste(dim(filtered_pos_2), collapse = "x"))

ggplot(filtered_pos_2, aes(x = pos, y = -(when_mutation_has_freq2), color = population)) +
  geom_point(size = 4) +
  labs(x = "Position", y = "log10 p-value", title = "Log10 p-value vs. Position for African Populations (1.8e+07 to 1.9e+07)") +
  theme_minimal() +
scale_color_manual(values = c("LWK" = "lightblue", "ESN" = "lightpink", "GWD" = "gold", "MSL" = "orange2", "YRI" = "lightgreen"))

# both populations are from Nigeria
# Out:
# Number of rows and columns: 6x36
# plot without title

# %%
# focus on region having overlapping genes(2.3e+07 to 2.4e+07)
filtered_pos_3 <- filtered[filtered$pos >= 2.3e+07 & filtered$pos <= 2.4e+07, ]
cat("Number of rows and columns:", paste(dim(filtered_pos_3), collapse = "x"))

ggplot(filtered_pos_3, aes(x = pos, y = -(when_mutation_has_freq2), color = population)) +
  geom_point(size = 3) +
  labs(x = "Position", y = "log10 p-value", title = "Log10 p-value vs. Position for African Populations (2.3e+07 to 2.4e+07)") +
  theme_minimal()
# Out:
# Number of rows and columns: 3x36
# plot without title

# %%
# focus on region having overlapping genes(3.5e+07 to 3.7e+07)
filtered_pos_4 <- filtered[filtered$pos >= 3.5e+07 & filtered$pos <= 3.7e+07, ]
cat("Number of rows and columns:", paste(dim(filtered_pos_3), collapse = "x"))

ggplot(filtered_pos_4, aes(x = pos, y = -(when_mutation_has_freq2), color = population)) +
  geom_point(size = 3) +
  labs(x = "Position", y = "log10 p-value", title = "Log10 p-value vs. Position for African Populations (3.5e+07 to 3.7e+07)") +
  theme_minimal()
# Out:
# Number of rows and columns: 3x36
# plot without title
